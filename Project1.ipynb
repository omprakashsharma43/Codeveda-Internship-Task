# %% [markdown]
# ##### Task : Explotrary Data Analysis (EDA)

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Generate synthetic Dataset

# %%
np.random.seed(42)  # For reproducibility
n_samples = 500

data = pd.DataFrame({
    "CRIM": np.random.rand(n_samples) * 10,  # crime rate
    "ZN": np.random.randint(0, 100, n_samples),  # residential land zone
    "INDUS": np.random.uniform(0, 30, n_samples),  # industry proportion
    "CHAS": np.random.randint(0, 2, n_samples),  # Charles River dummy variable
    "NOX": np.random.uniform(0.3, 0.8, n_samples),  # nitric oxide concentration
    "RM": np.random.normal(6, 0.5, n_samples),  # avg rooms per dwelling
    "AGE": np.random.randint(20, 100, n_samples),  # age of houses
    "DIS": np.random.uniform(1, 12, n_samples),  # distance to employment centres
    "RAD": np.random.randint(1, 10, n_samples),  # accessibility to highways
    "TAX": np.random.randint(200, 700, n_samples),  # property tax
    "PTRATIO": np.random.uniform(12, 22, n_samples),  # pupil-teacher ratio
    "B": np.random.uniform(100, 400, n_samples),  # proportion of blacks
    "LSTAT": np.random.uniform(1, 40, n_samples),  # lower status population %
    "MEDV": np.random.uniform(5, 50, n_samples)   # median house value (target)
})

data
# Out:
#          CRIM  ZN      INDUS  CHAS       NOX        RM  AGE        DIS  RAD  \
# 0    3.745401  62  22.327490     1  0.374852  6.791394   56   3.191974    3
# 1    9.507143  16   6.167394     1  0.511972  6.137341   25  10.652171    1
# 2    7.319939  72  23.633697     1  0.376492  6.178812   26   9.125955    5
# 3    5.986585  32  18.111646     0  0.417618  5.581340   44   1.151201    4
# 4    1.560186  83   3.428019     1  0.734630  5.751251   52   3.732139    9
# ..        ...  ..        ...   ...       ...       ...  ...        ...  ...
# 495  3.533522  39  23.514977     1  0.789031  5.640378   60  11.669192    4
# 496  5.836561  14  14.427115     0  0.696995  5.618426   61   7.283865    6
# 497  0.777346  20   1.222623     1  0.548628  6.067877   69   2.573012    9
# 498  9.743948  46   4.919984     0  0.469889  5.237647   59   5.120031    8
# 499  9.862107  72  13.158216     1  0.736068  5.323220   58   9.775055    1
#
#      TAX    PTRATIO           B      LSTAT       MEDV
# ...

# %% [markdown]
#  Summary Statistics

# %%
print("\nSummary Statistics:\n")
data.describe()
# Out:
# Summary Statistics:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     4.985617   48.036000   15.541181    0.504000    0.541983    6.001177
# std      2.986884   29.316986    8.827066    0.500485    0.143005    0.479066
# min      0.050616    0.000000    0.007126    0.000000    0.300166    4.684284
# 25%      2.412797   23.000000    7.973842    0.000000    0.413867    5.669366
# 50%      5.131637   49.000000   15.859641    1.000000    0.540065    6.014149
# 75%      7.561249   73.000000   23.229812    1.000000    0.667962    6.315964
# max      9.929648   99.000000   29.980605    1.000000    0.797740    7.336755
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    60.098000    6.480564    4.930000  448.526000   16.909034  248.840756
# ...

# %% [markdown]
# Visualizations

# %%
# Histograms
data.hist(bins=20, figsize=(15, 10))
plt.suptitle("Histograms of Features", fontsize=16)
plt.show()

# Box plots
plt.figure(figsize=(15, 8))
sns.boxplot(data=data, orient="h")
plt.title("Box Plots of Features")
plt.show()

# Scatter plot example (RM vs MEDV)
plt.figure(figsize=(7, 5))
sns.scatterplot(x="RM", y="MEDV", data=data)
plt.title("Scatter Plot: Rooms vs House Value")
plt.show()

# %% [markdown]
# Correlation Matrix & Heatmap

# %%
plt.figure(figsize=(12, 8))
corr = data.corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# Insights (you can extend this section in a report)

# %%
print("\nInsights:")
print("- RM (number of rooms) likely has a positive correlation with MEDV (house price).")
print("- LSTAT (lower status population %) likely has a negative correlation with MEDV.")
print("- TAX and RAD may show high correlation (multicollinearity).")
# Out:
# Insights:
# - RM (number of rooms) likely has a positive correlation with MEDV (house price).
# - LSTAT (lower status population %) likely has a negative correlation with MEDV.
# - TAX and RAD may show high correlation (multicollinearity).
